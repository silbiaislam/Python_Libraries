# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Car_sales.csv')

# %%
df
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
#help(pd.pivot)

# %%
division = df[['Manufacturer','Model','Sales_in_thousands']]

# %%
division
# Out:
#     Manufacturer    Model  Sales_in_thousands
# 0          Acura  Integra              16.919
# 1          Acura       TL              39.384
# 2          Acura       CL              14.114
# 3          Acura       RL               8.588
# 4           Audi       A4              20.397
# ..           ...      ...                 ...
# 152        Volvo      V40               3.545
# 153        Volvo      S70              15.245
# 154        Volvo      V70              17.531
# 155        Volvo      C70               3.493
# 156        Volvo      S80              18.969
#
# [157 rows x 3 columns]

# %%
pd.pivot(data=division,index='Manufacturer',columns='Model',values='Sales_in_thousands')
# Out:
# Model          3-Sep  3000GT    300M    323i   328i  4Runner  5-Sep    528i  \
# Manufacturer
# Acura            NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Audi             NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# BMW              NaN     NaN     NaN  19.747  9.231      NaN    NaN  17.527
# Buick            NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Cadillac         NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Chevrolet        NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Chrysler         NaN     NaN  30.696     NaN    NaN      NaN    NaN     NaN
# Dodge            NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Ford             NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Honda            NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# Hyundai          NaN     NaN     NaN     NaN    NaN      NaN    NaN     NaN
# ...

# %%
pd.pivot_table(df,index="Manufacturer",aggfunc='sum',values=['Sales_in_thousands','Fuel_capacity'])
# Out:
#               Fuel_capacity  Sales_in_thousands
# Manufacturer
# Acura                  65.6              79.005
# Audi                   58.6              40.557
# BMW                    51.7              46.505
# Buick                  71.0             242.019
# Cadillac              104.0             112.178
# Chevrolet             139.3             554.365
# Chrysler               98.9             201.721
# Dodge                 237.4             910.149
# Ford                  209.7            2022.635
# Honda                  85.4             592.674
# Hyundai                43.6             137.326
# Infiniti               18.5              23.713
# Jaguar                 18.4              15.467
# Jeep                   59.5             293.153
# Lexus                 123.2             106.843
# Lincoln                69.0              85.634
# Mercedes-B            170.3             117.125
# Mercury               107.0             237.999
# ...

# %%
pd.pivot_table(df,index=['Vehicle_type','Manufacturer'],values=['Sales_in_thousands'],aggfunc='sum')
# Out:
#                            Sales_in_thousands
# Vehicle_type Manufacturer
# Car          Cadillac                  14.785
#              Chrysler                  53.480
#              Dodge                    669.251
#              Ford                    1319.083
#              Honda                    162.087
#              Jeep                     293.153
#              Lexus                     60.364
#              Lincoln                   22.925
#              Mercedes-B                28.976
#              Mercury                   47.989
#              Mitsubishi                50.685
#              Nissan                   189.045
#              Oldsmobile                44.378
#              Plymouth                  24.155
#              Pontiac                   39.572
#              Subaru                    33.028
#              Toyota                   252.558
# Passenger    Acura                     79.005
#              Audi                      40.557
# ...
